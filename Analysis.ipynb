# %%
import pandas as pd
#b_q1 = pd.read_csv('b_data/b_q1.csv')
#p_df = pd.read_csv('perspective_final_normalized.csv')
#b_q1.head()

# %%
b_q1 = pd.read_csv('b_data/b_q6.csv')
corr = b_q1.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
print(corr)
# Out:
#                      q1  q1_in_text  q1_in_image  q1_in_speaker  q1_other
# q1             1.000000   -0.140197     0.024146       0.513102 -0.263774
# q1_in_text    -0.140197    1.000000     0.252860      -0.255270 -0.651450
# q1_in_image    0.024146    0.252860     1.000000       0.024215 -0.487941
# q1_in_speaker  0.513102   -0.255270     0.024215       1.000000 -0.519981
# q1_other      -0.263774   -0.651450    -0.487941      -0.519981  1.000000

# %%
b_q1 = pd.read_csv('b_data/b_q6.csv')
corr = b_q1.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
print(corr)
# Out:
#                      q6  q6_in_text  q6_in_image  q6_in_speaker  q6_other
# q6             1.000000    0.115632    -0.032635       0.364622 -0.482317
# q6_in_text     0.115632    1.000000     0.712274      -0.503576 -0.360851
# q6_in_image   -0.032635    0.712274     1.000000      -0.434828 -0.251970
# q6_in_speaker  0.364622   -0.503576    -0.434828       1.000000 -0.618398
# q6_other      -0.482317   -0.360851    -0.251970      -0.618398  1.000000

# %%
b_complete = pd.read_csv('b_data/b_complete.csv')
corr = b_complete.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
print(corr)
# Out:
#               answer   in_text  in_image  in_speaker     other
# answer      1.000000 -0.148325  0.006553   -0.118602  0.175282
# in_text    -0.148325  1.000000  0.264690    0.012600 -0.689850
# in_image    0.006553  0.264690  1.000000    0.104001 -0.405661
# in_speaker -0.118602  0.012600  0.104001    1.000000 -0.715032
# other       0.175282 -0.689850 -0.405661   -0.715032  1.000000

# %%
p_complete = pd.read_csv('p_data/p_complete.csv')
corr = p_complete.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
print(corr)
# Out:
#              answers   in_text  in_image  in_speaker     other
# answers     1.000000  0.007604 -0.088048    0.189007 -0.161201
# in_text     0.007604  1.000000  0.256921   -0.407460 -0.256837
# in_image   -0.088048  0.256921  1.000000   -0.196860 -0.344281
# in_speaker  0.189007 -0.407460 -0.196860    1.000000 -0.705774
# other      -0.161201 -0.256837 -0.344281   -0.705774  1.000000

# %%
complete_df = pd.read_csv('final_data_complete.csv')
corr = complete_df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
print(corr)
# Out:
#               answer   in_text  in_image  in_speaker     other
# answer      1.000000 -0.060838 -0.067361    0.066767  0.001280
# in_text    -0.060838  1.000000  0.150832   -0.220482 -0.478034
# in_image   -0.067361  0.150832  1.000000   -0.090738 -0.328326
# in_speaker  0.066767 -0.220482 -0.090738    1.000000 -0.696646
# other       0.001280 -0.478034 -0.328326   -0.696646  1.000000

# %%
df = pd.read_csv('b_data/b_complete.csv')
df.corr()
# Out:
#               answer   in_text  in_image  in_speaker     other
# answer      1.000000 -0.148325  0.006553   -0.118602  0.175282
# in_text    -0.148325  1.000000  0.264690    0.012600 -0.689850
# in_image    0.006553  0.264690  1.000000    0.104001 -0.405661
# in_speaker -0.118602  0.012600  0.104001    1.000000 -0.715032
# other       0.175282 -0.689850 -0.405661   -0.715032  1.000000

# %%
df2 = pd.read_csv('p_data/p_complete.csv')
df2.corr()
# Out:
#              answers   in_text  in_image  in_speaker     other
# answers     1.000000  0.007604 -0.088048    0.189007 -0.161201
# in_text     0.007604  1.000000  0.256921   -0.407460 -0.256837
# in_image   -0.088048  0.256921  1.000000   -0.196860 -0.344281
# in_speaker  0.189007 -0.407460 -0.196860    1.000000 -0.705774
# other      -0.161201 -0.256837 -0.344281   -0.705774  1.000000

# %%
b1_df = pd.read_csv('b_data/b_final_max.csv')
b1_df.corr()
# Out:
#               answer   in_text  in_image  in_speaker
# answer      1.000000 -0.000218  0.127472   -0.069567
# in_text    -0.000218  1.000000 -0.178319   -0.843132
# in_image    0.127472 -0.178319  1.000000   -0.378736
# in_speaker -0.069567 -0.843132 -0.378736    1.000000

# %%
from scipy.stats import pearsonr
pearsonr(df['answer'], df['in_image'])
# Out:
# (0.006553276655707744, 0.9494732267176078)

# %%
from scipy.stats import pearsonr
import pandas as pd

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

df = pd.read_csv('p_data/p_complete.csv')
calculate_pvalues(df)
# Out:
#            answers in_text in_image in_speaker   other
# answers          0  0.9343   0.3389     0.0387  0.0786
# in_text     0.9343       0   0.0046          0  0.0046
# in_image    0.3389  0.0046        0     0.0312  0.0001
# in_speaker  0.0387       0   0.0312          0       0
# other       0.0786  0.0046   0.0001          0       0

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["Text Score",
          "Visual Score",
          "Other",
         "Speaker Score"]

data = [58, 9, 30, 11]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Frequency of Classes")

plt.show()
